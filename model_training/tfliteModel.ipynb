# %%
import tensorflow as tf

# Load model if needed
model = tf.keras.models.load_model(r"real_fake_model.keras")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]   # Quantization for smaller size
tflite_model = converter.convert()

# Save tflite model
with open("cifake_model.tflite", "wb") as f:
    f.write(tflite_model)

print("TFLite model saved!")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\VIVECH~1\AppData\Local\Temp\tmpr85wr38q\assets
# INFO:tensorflow:Assets written to: C:\Users\VIVECH~1\AppData\Local\Temp\tmpr85wr38q\assets
# Saved artifact at 'C:\Users\VIVECH~1\AppData\Local\Temp\tmpr85wr38q'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 240, 240, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2054365294288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054365295632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054365296016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054365295056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054365295824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054365297168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054365298320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054365297936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054366872208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2054366873168: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model saved!
